# %%
from pprint import pprint as print
from gensim.models.fasttext import FastText as FT_gensim
from gensim.test.utils import datapath

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
path = '/Users/stefanoraimondousai/Documents/ReadingCourse/WikiItaliaGennaio2019.txt' 
corpus= datapath(path)

# %%
model = FT_gensim(size=300, min_count=50, sg=1, negative=10)
# Out:
# 2020-03-31 20:23:33,968 : INFO : resetting layer weights

# %%
model.build_vocab(corpus_file=corpus)
# Out:
# 2020-03-31 20:26:53,351 : INFO : PROGRESS: at sentence #7780000, processed 316786848 words, keeping 6135871 word types
# 2020-03-31 20:26:53,497 : INFO : PROGRESS: at sentence #7790000, processed 317143361 words, keeping 6140630 word types
# 2020-03-31 20:26:53,638 : INFO : PROGRESS: at sentence #7800000, processed 317491198 words, keeping 6144912 word types
# 2020-03-31 20:26:53,786 : INFO : PROGRESS: at sentence #7810000, processed 317865757 words, keeping 6149902 word types
# 2020-03-31 20:26:53,926 : INFO : PROGRESS: at sentence #7820000, processed 318205888 words, keeping 6154557 word types
# 2020-03-31 20:26:54,065 : INFO : PROGRESS: at sentence #7830000, processed 318556248 words, keeping 6159166 word types
# 2020-03-31 20:26:54,202 : INFO : PROGRESS: at sentence #7840000, processed 318897637 words, keeping 6163768 word types
# 2020-03-31 20:26:54,328 : INFO : PROGRESS: at sentence #7850000, processed 319209913 words, keeping 6167700 word types
# ...

# %%
model.train(
    corpus_file=corpus, epochs=model.epochs,
    total_examples=model.corpus_count, total_words=model.corpus_total_words
)
# Out:
# 2020-03-31 20:35:55,921 : INFO : training model with 3 workers on 255789 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=10 window=5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-a72a2560874a> in <module>
#       1 model.train(
#       2     corpus_file=corpus, epochs=model.epochs,
# ----> 3     total_examples=model.corpus_count, total_words=model.corpus_total_words
#       4 )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gensim/models/fasttext.py in train(self, sentences, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, callbacks, **kwargs)
#     920             sentences=sentences, corpus_file=corpus_file, total_examples=total_examples, total_words=total_words,
#     921             epochs=epochs, start_alpha=start_alpha, end_alpha=end_alpha, word_count=word_count,
# ...

# %%
model.save()

# %%
print(model.most_similar("ricospyo", topn=50))
# Out:
# /Users/stefanoraimondousai/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# 2020-03-31 20:22:34,158 : INFO : precomputing L2-norms of word weight vectors
# 2020-03-31 20:22:34,163 : INFO : precomputing L2-norms of ngram weight vectors
# [('fosse', 0.8431062698364258),
#  ('se', 0.8428670167922974),
#  ('E', 0.8427743911743164),
#  ('forse', 0.8423969745635986),
#  ('inglese', 0.8423658013343811),
#  ('30', 0.8422648310661316),
#  ('modo', 0.8421052694320679),
#  ('funzione', 0.84209144115448),
#  ('20', 0.8420799970626831),
#  ('due', 0.8420777916908264),
#  ('libro', 0.8420733213424683),
#  ('invece', 0.8420374393463135),
#  ('cs', 0.841894805431366),
#  ('base', 0.8418923616409302),
#  ('funziona', 0.8417947292327881),
#  ('insieme', 0.8416602611541748),
#  ('9', 0.8414006233215332),
# ...

# %%
model.predict_output_word(['giovedì', 'andiamo', 'a'], topn=40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-452db593e59f> in <module>
# ----> 1 model.predict_output_word(['giovedì', 'andiamo', 'a'], topn=40)
#
# AttributeError: 'FastText' object has no attribute 'predict_output_word'

# %%
import tempfile
import os
with tempfile.NamedTemporaryFile(prefix='saved_model_gensim-', delete=False) as tmp:
    model.save(tmp.name, separately=[])
# Out:
# 2020-03-31 20:17:09,757 : INFO : saving FastText object under /var/folders/pp/x01r345d0tbfh04c_hyr0fp80000gn/T/saved_model_gensim-xtoj3u5k, separately []
# 2020-03-31 20:17:09,759 : INFO : storing np array 'vectors_ngrams' to /var/folders/pp/x01r345d0tbfh04c_hyr0fp80000gn/T/saved_model_gensim-xtoj3u5k.wv.vectors_ngrams.npy
# 2020-03-31 20:17:21,419 : INFO : not storing attribute vectors_ngrams_norm
# 2020-03-31 20:17:21,439 : INFO : not storing attribute vectors_norm
# 2020-03-31 20:17:21,441 : INFO : not storing attribute vectors_vocab_norm
# 2020-03-31 20:17:21,442 : INFO : not storing attribute buckets_word
# 2020-03-31 20:17:21,444 : INFO : storing np array 'vectors_ngrams_lockf' to /var/folders/pp/x01r345d0tbfh04c_hyr0fp80000gn/T/saved_model_gensim-xtoj3u5k.trainables.vectors_ngrams_lockf.npy
# 2020-03-31 20:17:27,744 : INFO : saved /var/folders/pp/x01r345d0tbfh04c_hyr0fp80000gn/T/saved_model_gensim-xtoj3u5k
