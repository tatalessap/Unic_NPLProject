# %%
import json

# %%
bad_word={}
with open ('onlyBadWords.json') as file:
    bad_word = json.load(file)

# %%
bad_word=bad_word.get('bad')

# %%
bad_word.pop(bad_word.index('eia'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-efd76e7af5db> in <module>
# ----> 1 bad_word.pop(bad_word.index('eia'))
#
# ValueError: 'eia' is not in list

# %%
text={}
# Out:
# ['❤️',
#  'pr2',
#  'eja',
#  'ms2',
#  '28m',
#  'hlr',
#  'oky',
#  'vlr',
#  'lho',
#  'eja',
#  'oky',
#  'mmh',
#  'eya',
#  'tmsi',
#  'sojo',
#  'gmsc',
#  'csmn',
#  'lide',
#  'prvo',
#  'lxml',
#  'ahah',
#  'lapp',
#  '0577',
#  'coem',
#  'ahah',
#  'logs',
#  'nont',
#  'uppo',
#  '4616',
#  'minca',
#  'gsmun',
#  'vabbe',
#  'l’eir',
#  'così🙈',
#  'impsi',
#  'punro',
#  'prusu',
#  'cicla',
#  'l’auc',
#  'baste',
#  'ahaha',
#  'aprto',
#  'modul',
#  'markq',
#  'lidea',
#  'minca',
#  'botdiv',
#  '093148',
#  'taglib',
#  'raosio',
#  'lavevo',
#  'ahahah',
#  'viston',
#  'freghi',
#  'webxml',
#  'ghiani',
#  'laltra',
#  'latosx',
#  'ghiani',
#  'webxmx',
#  'rebase',
#  'accedi',
#  'dacqua',
#  'farela',
#  'okpure',
#  'lonore',
#  'iniando',
#  'unaltra',
#  'zippati',
#  'lezioji',
#  'abcheca',
#  'lultima',
#  'eudorom',
#  'nattimo',
#  'callona',
#  'agyimon',
#  'padrema',
#  'bagassa',
#  'lheader',
#  'limport',
#  'disigio',
#  'dallide',
#  'lerrore',
#  'ridanno',
#  'newpost',
#  'prefixc',
#  'foreach',
#  'lultimo',
#  'turtoiu',
#  'unodore',
#  'netbeans',
#  'cosuccia',
#  'incasina',
#  'inciando',
#  'l’intera',
#  'refactor',
#  'portarti',
#  'sessohai',
#  'equiment',
#  'incasini',
#  'mandarti',
#  'sputtana',
#  'seguirti',
#  'infogato',
#  'offrirti',
#  'avertelo',
#  'stoppalo',
#  'un’altra',
#  'l’utente',
#  'scaricar',
#  'annulato',
#  'preesame',
#  'postlato',
#  'cforeach',
#  'pizzetta',
#  'riprendi',
#  'l’ultimo',
#  'lavevamo',
#  'milleggo',
#  'dellidea',
#  'varlista',
#  'ahahahah',
#  'portarmi',
#  'sullhtml',
#  'ahahahha',
#  'protebbe',
#  'all’imei',
#  'okattimo',
#  '23112016',
#  'sullorlo',
#  'literator',
#  'prossiman',
#  'arrabiata',
#  'divertite',
#  'giovedì😓❓',
#  'aranzulla',
#  'rivedermi',
#  'prevented',
#  'minchiate',
#  'visitator',
#  'risaliamo',
#  'staccaaah',
#  'allultima',
#  'altrimeti',
#  'improvisa',
#  'pigliando',
#  'allerrore',
#  'salutaper',
#  'personeno',
#  'sclerando',
#  'nellaltro',
#  'stuprando',
#  'mandamelo',
#  'glassfish',
#  'attriburi',
#  'hyperframe',
#  'superframe',
#  'utentenome',
#  'multiframe',
#  'colazione😔',
#  'pullstrean',
#  'ricordarti',
#  'profilojsp',
#  'multiframe',
#  'lesercizio',
#  'rimandarmi',
#  'proggramma',
#  'monteclaro',
#  'fulfilling',
#  'sfanculato',
#  'santefisio',
#  'sfanculano',
#  'presuposto',
#  'distrastro',
#  'sputtanano',
#  'lattributo',
#  'superframe',
#  'encountered',
#  'dell’utente',
#  'deployedsee',
#  'scrivertela',
#  'ispirandomi',
#  'transceiver',
#  'hotspottato',
#  'collissione',
#  'commentarlo',
#  'presenterai',
#  'scriveresse',
#  'multiframe3',
#  'delprogetto',
#  'controllavo',
#  'connettwrmi',
#  'ricontrollo',
#  'manunteroee',
#  'sorellina29',
#  'detailsbuild',
#  'rimandarmelo',
#  'completatose',
#  'passwordroot',
#  'stalkeraggio',
#  'dell’handover',
#  'cognomeutente',
#  'modelliclassj',
#  'modelliclassi',
#  'listaforeachi',
#  'modelliservlet',
#  'nomeutenteroot',
#  'semipermanenti',
#  'nomeutentenote',
#  'riorganizzarle',
#  'webapplication1',
#  'gruppinomegroup',
#  'autentificazione',
#  'utentenomeutente',
#  'itemslistagruppi',
#  'utentiregistrati',
#  'geolocalizzazionw',
#  'dellincapsulamento',
#  'thislistautentiaddi',
#  'profilolinserimento',
#  'errordescriptionthe',
#  'liplistanamegrouppli',
#  'reportmessageinternal']
